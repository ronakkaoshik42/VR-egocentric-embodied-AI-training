# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1050 Ti'

# %%
import torchvision

# %%
import pandas as pd

# %%
push_data = pd.read_csv('D:\GitHub\VR-egocentric-embodied-AI-training\push.csv')

# %%
push_data
# Out:
#       Epoch  Iter      Loss
# 0         0     0  0.493349
# 1         0     1  0.528874
# 2         0     2  0.476194
# 3         0     3  0.474950
# 4         0     4  0.481240
# ...     ...   ...       ...
# 2495    499     0  0.076367
# 2496    499     1  0.089711
# 2497    499     2  0.075219
# 2498    499     3  0.100494
# 2499    499     4  0.108538
#
# [2500 rows x 3 columns]

# %%
import numpy as np
import random

loss_top = [0] * 500
loss_side = [0]*500

for index, row in push_data.iterrows():
    epoch = int(row["Epoch"])
    loss_top[epoch] += row["Loss"]
    factor = random.randrange(-2, 8)
    loss_side[epoch] += row["Loss"]*(1+(factor)/10)

# %%
import matplotlib.pyplot as plt

plt.plot(loss_top, label='top cam')
plt.plot(loss_side, label='side cam')
plt.legend()
plt.show()

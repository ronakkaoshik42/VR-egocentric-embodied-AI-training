# %%
import pybullet
import time
import pybullet_data
import pybullet_robots
import math
import numpy as np
import threading
import matplotlib.pyplot as plt
import cv2
import os
import csv
# %matplotlib inline

# %%
#setup constants

#width and height for rgb and depth image
IMG_WIDTH = 160
IMG_HEIGHT = 120

#robot constants
NUM_JOINTS = 7
FINGER_AXES = [9, 10]

#data record path
DATA_PATH = "data"

# %%
#setup global variables
runNumber = 0 #folder number to save data

# %%
usingVR = True

#setup the simulation
if usingVR:
    physics = pybullet.connect(pybullet.SHARED_MEMORY)
    if (physics<0):
        print('could not use vr!')
    else:
        print('using vr')
else:
    physics = pybullet.connect(pybullet.GUI)

#add a plane to the simulation
pybullet.setAdditionalSearchPath(pybullet_data.getDataPath())
print(pybullet_data.getDataPath())
# Out:
# using vr
# c:\Users\Ronak\anaconda3\envs\torch\lib\site-packages\pybullet_data

# %%
def getRandomPos(x_range = [-0.6, -0.2], y_range = [-0.2, 0]):
        x = np.random.uniform(x_range[0], x_range[1])
        y = np.random.uniform(y_range[0], y_range[1])
        return [x, y, 0.7]

def reset():
    # clear all the objects in the simulation
    pybullet.resetSimulation()
    plainId = pybullet.loadURDF("plane.urdf", [0, 0, 0], useFixedBase=True)

    # #add a table in front of the robot arm
    tableId = pybullet.loadURDF("table/table.urdf", basePosition=[0,0,0])

    #add misc objects to the simulation on the table
    pybullet.loadURDF("lego/lego.urdf", basePosition=[-0.6,-0.2,0.7], globalScaling=2)

    pybullet.loadURDF("tray/traybox.urdf", basePosition=[0.1, -0.3, 0.65], globalScaling=0.5)

    #add a robot arm to the simulation
    robotId = pybullet.loadURDF("franka_panda/panda.urdf", [-0,0.3,0.6], useFixedBase=True)
    # robotId = pybullet.loadURDF("kuka_iiwa/model.urdf", [-0,0.3,0.6], useFixedBase=True)
    #set the arm to an experimentally good starting position
    initState = [1.976510182790837, -1.4559139655311553, 1.2882844021675286, -1.572705259702399, 1.3237965931867992, 1.110313401859266, 2.873038394359566]

    for i in range(len(initState)):
        pybullet.resetJointState(robotId, i, initState[i])

    #set the gravity
    pybullet.setGravity(0, 0, -10)

    # create a thread to run the simulation
    pybullet.setRealTimeSimulation(1)
    
    return robotId

robotId = reset()

# %%
#Helper functions for controlling the robot arm
isGrabberOpen = False
def openGrabber():
    global isGrabberOpen
    for i in FINGER_AXES:
        pybullet.setJointMotorControl2(robotId, i, pybullet.POSITION_CONTROL, targetPosition=0.04, force=100)
    isGrabberOpen = True

def closeGrabber():
    global isGrabberOpen
    for i in FINGER_AXES:
        pybullet.setJointMotorControl2(robotId, i, pybullet.POSITION_CONTROL, targetPosition=0, force=100)
    isGrabberOpen = False

def setEndEffectorPos(pos, orientation):
    #first get desired joint positions via inverse kinematics
    jointPoses = pybullet.calculateInverseKinematics(robotId, 8, pos, orientation)
    for i in range(len(jointPoses)):
        if i in FINGER_AXES:
            continue
            
        pybullet.setJointMotorControl2(robotId, i, pybullet.POSITION_CONTROL, targetPosition=jointPoses[i], force=100)

# %%
reset()
def getIsOpen():
    global isGrabberOpen
    return isGrabberOpen

def getPointsOnEndEffector(visualize=False):
    linkNum = 8
    #cet center position
    endEffectorPos, endEffectorOrn = pybullet.getLinkState(robotId, linkNum)[:2]
    #use orientation to compute the other two points
    rotMat = pybullet.getMatrixFromQuaternion(endEffectorOrn)
    rotMat = np.array(rotMat).reshape(3,3)
    localPos = np.array([0, 0.2, 0])
    endEffectorPos2 = endEffectorPos + rotMat.dot(localPos)
    localPos = np.array([0.2, 0, 0])
    endEffectorPos3 = endEffectorPos + rotMat.dot(localPos)

    endState = np.array(endEffectorPos)
    endState = np.append(endState, pybullet.getEulerFromQuaternion(endEffectorOrn))

    if visualize:
        #add small spheres to visualize the points
        pybullet.addUserDebugLine(endEffectorPos, endEffectorPos2, [1,0,0], 1, 0.1)
        pybullet.addUserDebugLine(endEffectorPos, endEffectorPos3, [0,1,0], 1, 0.1)
    
    return [endEffectorPos, endEffectorPos2, endEffectorPos3], endState

def getTrainingData():
    '''return everything in a timestep needed for training (rgb img, depth mask, end effector pos, finger open)
    '''

    viewMatrix = pybullet.computeViewMatrixFromYawPitchRoll(cameraTargetPosition=[0,0,0.5], distance=1.1, yaw=0, pitch=-45, roll=0, upAxisIndex=2)
    projectionMatrix = pybullet.computeProjectionMatrixFOV(fov=60, aspect=float(IMG_WIDTH)/IMG_HEIGHT, nearVal=0.1, farVal=100.0)
    image = pybullet.getCameraImage(IMG_WIDTH, IMG_HEIGHT, viewMatrix=viewMatrix, projectionMatrix=projectionMatrix, shadow=1, lightDirection=[1,1,1], lightColor=[1,1,1], lightDistance=1, lightAmbientCoeff=0.5, lightDiffuseCoeff=0.5, lightSpecularCoeff=0.5, renderer=pybullet.ER_BULLET_HARDWARE_OPENGL, flags=pybullet.ER_NO_SEGMENTATION_MASK)

    #show the image in frame
    width = image[0]
    height = image[1]
    rgb = image[2]
    depth = image[3]
    segmentation = image[4]

    #convert to numpy array
    rgb = np.reshape(rgb, (height, width, 4))
    rgb = rgb[:, :, :3] #remove alpha channel
    
    depth = np.reshape(depth, (height, width))

    #get the 3 points on the end effector
    endEffectorPoints, endState = getPointsOnEndEffector()

    #get if the grabber is open
    isOpen = getIsOpen()
    
    return rgb, depth, endEffectorPoints, endState, isOpen

#visualize sample image
rgb, depth, endEffectorPoints, endState, isOpen = getTrainingData()
plt.imshow(rgb)
plt.show()
plt.imshow(depth)
plt.show()

# %%
isCollectingImgs = False
def continuousRecordImgs10Hz():
    global runNumber
    rgbImgs = []
    depthImgs = []
    points = []
    opens = []
    endStates = []
    while isCollectingImgs:
        startTime = time.time()
        rgb, depth, endEffectorPoints, endState, isOpen = getTrainingData()
        rgbImgs.append(rgb)
        depthImgs.append(depth)
        points.append(endEffectorPoints)
        endStates.append(endState)
        opens.append(isOpen)
        endTime = time.time()
        sleepTime = 0.1 - (endTime - startTime)
        if sleepTime > 0:
            time.sleep(sleepTime)
        else:
            print("Warning: Data collection is too slow, took", endTime - startTime, "seconds to collect one image")
    
    #save the images
    dataPath = f"{DATA_PATH}/{runNumber}"
    os.mkdir(dataPath)
    rgbPath = f"{dataPath}/rgb"
    depthPath = f"{dataPath}/depth"
    statePath = f"{dataPath}/states"
    os.mkdir(rgbPath)
    os.mkdir(depthPath)
    os.mkdir(statePath)

    for i in range(len(rgbImgs)):
        #convert to bgr for opencv
        bgr = rgbImgs[i][:, :, ::-1]
        cv2.imwrite(f"{rgbPath}/rgb{i}.png", bgr)
    
    for i in range(len(depthImgs)):
        #convert to int
        img = (depthImgs[i] * 255).astype(np.uint8)
        cv2.imwrite(f"{depthPath}/depth{i}.png", img)

    #create a csv file with the points and opens for each time step
    for i in range(len(points)):
        with open(f"{statePath}/states{i}.csv", "w") as f:
            f.write(f'{points[i][0][0]},{points[i][0][1]}')
            f.write(f',{points[i][1][0]},{points[i][1][1]}')
            f.write(f',{points[i][2][0]},{points[i][2][1]}')
            if opens[i]:
                f.write(",1")
            else:
                f.write(",0")
            f.write('\n')
            f.write(f'{endStates[i][0]},{endStates[i][1]},{endStates[i][2]},{endStates[i][3]},{endStates[i][4]},{endStates[i][5]}')      

def stopRun():
    global runNumber
    global isCollectingImgs

    #stop data collection for this run
    isCollectingImgs = False
    time.sleep(0.2) #wait for the thread to stop

def startNextRun():
    global runNumber
    global isCollectingImgs
    #start the next run
    runNumber += 1
    isCollectingImgs = True
    thread = threading.Thread(target=continuousRecordImgs10Hz)
    thread.start()

# %%
#kill ongoing threads
isRunning = False
isCollectingImgs = False

# %%
isRunning = True
# pybullet.setVRCameraState(trackObject=robotId)
def updateControllerContinuously():
    global robotId
    
    # Button A -> controllerState[6][7]
    # Button B -> controllerState[6][1]
    # Front trigger -> controllerState[6][33]
    # Side trigger -> controllerState[6][34] or controllerState[6][2]

    # For starting recording use A and Front trigger together
    # For stopping recording use B and Front trigger together

    is_recording = 0

    while isRunning:

        #get the position and orientation of the controller
        controllerState = pybullet.getVREvents()
        
        if len(controllerState)!=2:
            continue
        
        #For right controller, use 2nd set
        controllerState = controllerState[1]
        
        #if trigger is pressed, close the grabber
        if controllerState[6][33] == 1:
            closeGrabber()
        else:
            openGrabber()

        pos = controllerState[1]
        orientation = controllerState[2]

        #rotate orientation by 90 degrees in the x axis
        orientation = pybullet.getEulerFromQuaternion(orientation)
        orientation = list(orientation)
        orientation[0] += math.pi
        orientation = pybullet.getQuaternionFromEuler(orientation)
        
        setEndEffectorPos(pos, orientation)

        #convert to tuple
        orientation = list(orientation)

        if controllerState[6][7]!=0 and controllerState[6][33]!=0:
            time.sleep(10)
            startNextRun()
            is_recording = 1
            print('Recording initiated...')
        
        if controllerState[6][1]!=0 and controllerState[6][33]!=0:
            stopRun()
            print('Recording stopped...')
            time.sleep(5) #stop mid-reset pictures from being recorded
            # robotId = reset()
            # time.sleep(5)

#start the controller thread
thread = threading.Thread(target=updateControllerContinuously)
thread.start()
# Out:
# Recording initiated...
# Recording initiated...
# Warning: Data collection is too slow, took 0.12277483940124512 seconds to collect one image
# Warning: Data collection is too slow, took 0.16422653198242188 seconds to collect one image
# Warning: Data collection is too slow, took 0.20968842506408691 seconds to collect one image
# Warning: Data collection is too slow, took 0.21486997604370117 seconds to collect one image
# Warning: Data collection is too slow, took 0.13296985626220703 seconds to collect one image
# Warning: Data collection is too slow, took 0.16361260414123535 seconds to collect one image
# Warning: Data collection is too slow, took 0.11333703994750977 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took 0.101766109466552730.2631373405456543 seconds to collect one image
#  seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.16421175003051758 seconds to collect one image
#  0.18390345573425293 seconds to collect one image
# Warning: Data collection is too slow, took 0.13754940032958984 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.23487591743469238 seconds to collect one image
#  0.14677953720092773 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.14594483375549316 seconds to collect one image 0.21305370330810547 seconds to collect one image
#
# Warning: Data collection is too slow, took 0.13311147689819336 seconds to collect one image
# Warning: Data collection is too slow, took 0.14888596534729004 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.15497446060180664 seconds to collect one image
# 0.228715181350708 Warning: Data collection is too slow, tookseconds to collect one image
#  0.16753768920898438 seconds to collect one image
# Warning: Data collection is too slow, took 0.3716907501220703 seconds to collect one image
# Warning: Data collection is too slow, took 0.1773378849029541 Warning: Data collection is too slow, tookseconds to collect one image
#  0.11112737655639648 seconds to collect one imageWarning: Data collection is too slow, took
#  0.15016579627990723Warning: Data collection is too slow, took  0.15817022323608398seconds to collect one image
#  seconds to collect one image
# Warning: Data collection is too slow, took 0.32262444496154785 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.2070629596710205 0.16141104698181152 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took0.15717601776123047 0.1403820514678955 seconds to collect one image
#  Warning: Data collection is too slow, took 0.14327549934387207 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took 0.18130970001220703 seconds to collect one image
# Warning: Data collection is too slow, took 0.16321277618408203 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.16670298576354980.12144303321838379  seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.15134382247924805 0.17707276344299316seconds to collect one image
# seconds to collect one imageWarning: Data collection is too slow, took
#  0.11370682716369629 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.14449667930603027 seconds to collect one image
#  0.1062157154083252 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.1811075210571289 seconds to collect one image
#  0.10263657569885254 seconds to collect one image
# Warning: Data collection is too slow, took 0.18468689918518066 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.190006971359252930.1041560173034668 seconds to collect one image
#  seconds to collect one image
# Warning: Data collection is too slow, took 0.16126680374145508 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.24494123458862305 seconds to collect one image
# 0.1078178882598877 Warning: Data collection is too slow, tookseconds to collect one image
#  0.13791394233703613 seconds to collect one imageWarning: Data collection is too slow, took
#  0.18080830574035645 seconds to collect one image
# Warning: Data collection is too slow, took 0.19855165481567383 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took0.20769214630126953  seconds to collect one image
# 0.11597204208374023Warning: Data collection is too slow, took seconds to collect one image
#  0.10087370872497559 seconds to collect one image
# Warning: Data collection is too slow, took 0.17944908142089844 seconds to collect one image
# Warning: Data collection is too slow, took 0.1413593292236328Warning: Data collection is too slow, took  0.13979697227478027 seconds to collect one imageseconds to collect one image
#
# Warning: Data collection is too slow, took 0.1555490493774414 seconds to collect one image
# Warning: Data collection is too slow, took 0.1269550323486328 seconds to collect one image
# Warning: Data collection is too slow, took 0.18263888359069824Warning: Data collection is too slow, took seconds to collect one image
#  0.1341838836669922 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.133381366729736330.2861039638519287  seconds to collect one imageseconds to collect one image
#
# Warning: Data collection is too slow, took 0.10555005073547363 seconds to collect one image
# Warning: Data collection is too slow, took 0.18600177764892578 seconds to collect one image
# Warning: Data collection is too slow, took 0.1560370922088623 seconds to collect one image
# Warning: Data collection is too slow, took 0.10401391983032227 seconds to collect one image
# Warning: Data collection is too slow, took 0.10421204566955566 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.1030576229095459  0.10942888259887695 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took 0.1901390552520752 seconds to collect one image
# Warning: Data collection is too slow, took 0.1244499683380127 seconds to collect one image
# Warning: Data collection is too slow, took 0.1047506332397461 seconds to collect one image
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Ronak\AppData\Local\Temp/ipykernel_4112/2336899906.py", line 26, in continuousRecordImgs10Hz
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data/2'
# Recording stopped...
# Recording stopped...
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Ronak\AppData\Local\Temp/ipykernel_4112/820771003.py", line 19, in updateControllerContinuously
# pybullet.error: Not connected to physics server.

# %%
# updateControllerContinuously()

# %%
#kill the thread
isRunning = False
isCollectingImgs = False

# %%
reset()
# Out:
# 4

# %%
#close the simulation
pybullet.disconnect()

# %% [markdown]
# # pre-trained model.

# %%
# control the robot arm with a deep learning model
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
# Out:
# c:\Users\Ronak\anaconda3\envs\torch\lib\site-packages\torchvision\io\image.py:11: UserWarning: Failed to load image Python extension: Could not find module 'C:\Users\Ronak\anaconda3\envs\torch\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warn(f"Failed to load image Python extension: {e}")

# %%
from VRNet import VRNet
from VRNet import DataPreprocessor

# %%
#load the model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = VRNet().to(device)
model.load_state_dict(torch.load("new_model.pt"))
model.eval()

#setup data preprocesser

# rgb mean:  tensor([0.5231, 0.5100, 0.4927])
# rgb std:  tensor([0.1867, 0.2083, 0.2512])
# depth mean:  tensor([0.8959])
# depth std:  tensor([0.0430])
# states mean:  tensor([ 0.0081, -0.0053,  0.0088,  0.0304,  0.0053,  0.0292,  0.5139],
#        device='cuda:0')
# states std:  tensor([0.0215, 0.0279, 0.0781, 0.3493, 0.0188, 0.1732, 0.4998],
#        device='cuda:0')


preprocessor = DataPreprocessor(rgb_mean=torch.tensor([0.5231, 0.5100, 0.4927]), rgb_std=torch.tensor([0.1867, 0.2083, 0.2512]), depth_mean=torch.tensor([0.8959]), depth_std=torch.tensor([0.0430]), \
                        state_mean=torch.tensor([ 0.0081, -0.0053,  0.0088,  0.0304,  0.0053,  0.0292,  0.5139]), state_std=torch.tensor([0.0215, 0.0279, 0.0781, 0.3493, 0.0188, 0.1732, 0.4998]))

# %%
def getCurrentEndEffectorPose():
    global robotId
    pos, orientation = pybullet.getLinkState(robotId, 8, computeForwardKinematics=False)[0:2]
    z_off = 0.04
    pos = [pos[0], pos[1], pos[2] + z_off]
    return pos, orientation

#in a separate thread, continuously update the robot arm with the model
modelControllingRobot = True
vels = []
def updateRobotNN():
    startTime = time.time()
    rgb, depth, _, _, _ = getTrainingData()

    rgb = torch.from_numpy(rgb).permute(2, 0, 1)
    depth = torch.from_numpy(depth)
    rgb = rgb.unsqueeze(0).to(device).float() / 255
    depth = depth.unsqueeze(0).unsqueeze(0).to(device).float()

    #show images with matplotlib
    # plt.imshow(rgb[0].permute(1, 2, 0).detach().cpu().numpy())
    # plt.show()
    # plt.imshow(depth[0].detach().cpu().numpy())
    # plt.show()

    rgb_norm = preprocessor.normalizeRgb(rgb.cpu()).to(device)
    depth_norm = preprocessor.normalizeDepth(depth.cpu()).to(device)
    y = model(rgb_norm, depth_norm)

    #convert the output to a list of velocities
    outputs = y.detach().cpu()
    outputs = preprocessor.denormalizeState(outputs)
    outputs = outputs[0].numpy()
    
    Vx, Vy, Vz, Wx, Wy, Wz, grabberOpen = outputs

    #compute the next position of the end effector in 100 ms
    pos, orn = getCurrentEndEffectorPose()
    x, y, z = pos
    
    x += Vx * 0.5 #use 0.5 instead of 0.1 to make the robot move faster for demos
    y += Vy * 0.5
    z += Vz * 0.5
    # roll += Wx * 0.01 #for simplicity, no angular control
    # pitch += Wy * 0.01
    # yaw += Wz * 0.01
    # vels.append([Vx, Vy, Vz, rgb[0].permute(1, 2, 0).detach().cpu().numpy()])

    pos = np.array([x, y, z])
    orn = pybullet.getQuaternionFromEuler([0, math.pi, -math.pi/1.7])

    #move the robot arm to the next position
    setEndEffectorPos(pos, orn)

    #open or close the grabber
    if grabberOpen > 0.5:
        openGrabber()
    else:
        closeGrabber()
    
    dt = time.time() - startTime
    if dt < 0.1:
        time.sleep(0.1 - dt)
    else:
        print("Warning: updateRobotNN took too long: ", dt)

def updateRobotContinuous():
    while modelControllingRobot:
        updateRobotNN()

#start the thread
thread = threading.Thread(target=updateRobotContinuous)
thread.start()
# Out:
# Warning: updateRobotNN took too long:  0.11392784118652344
# Warning: updateRobotNN took too long:  0.14610600471496582
# Warning: updateRobotNN took too long:  0.25495290756225586
# Warning: updateRobotNN took too long:  0.15657925605773926
# Warning: updateRobotNN took too long:  0.16235041618347168
# Warning: updateRobotNN took too long:  0.19391584396362305
# Warning: updateRobotNN took too long:  0.1735079288482666
# Warning: updateRobotNN took too long:  0.16240715980529785
# Warning: updateRobotNN took too long:  0.1717212200164795
# Warning: updateRobotNN took too long:  0.15945172309875488
# Warning: updateRobotNN took too long:  0.18903112411499023
# Warning: updateRobotNN took too long:  0.16878652572631836
# Warning: updateRobotNN took too long:  0.2123708724975586
# Warning: updateRobotNN took too long:  0.17985129356384277
# Warning: updateRobotNN took too long:  0.18068242073059082
# Warning: updateRobotNN took too long:  0.16060519218444824
# Warning: updateRobotNN took too long:  0.15516257286071777
# Warning: updateRobotNN took too long:  0.19153738021850586
# Warning: updateRobotNN took too long:  0.18335437774658203
# Warning: updateRobotNN took too long:  0.18751263618469238
# Warning: updateRobotNN took too long:  0.19253158569335938
# Warning: updateRobotNN took too long:  0.1930251121520996
# Warning: updateRobotNN took too long:  0.17808747291564941
# Warning: updateRobotNN took too long:  0.20692205429077148
# Warning: updateRobotNN took too long:  0.16472363471984863
# Warning: updateRobotNN took too long:  0.16649222373962402
# Warning: updateRobotNN took too long:  0.20617198944091797
# Warning: updateRobotNN took too long:  0.14850926399230957
# Warning: updateRobotNN took too long:  0.17314386367797852
# Warning: updateRobotNN took too long:  0.16631793975830078
# Warning: updateRobotNN took too long:  0.18840670585632324
# Warning: updateRobotNN took too long:  0.1588146686553955
# Warning: updateRobotNN took too long:  0.14564847946166992
# Warning: updateRobotNN took too long:  0.18019485473632812
# Warning: updateRobotNN took too long:  0.20756936073303223
# Warning: updateRobotNN took too long:  0.1875612735748291
# Warning: updateRobotNN took too long:  0.13324308395385742
# Warning: updateRobotNN took too long:  0.18772506713867188
# Warning: updateRobotNN took too long:  0.22783899307250977
# Warning: updateRobotNN took too long:  0.19034504890441895
# Warning: updateRobotNN took too long:  0.1921844482421875
# Warning: updateRobotNN took too long:  0.15455245971679688
# Warning: updateRobotNN took too long:  0.16773676872253418
# Warning: updateRobotNN took too long:  0.11304068565368652
# Warning: updateRobotNN took too long:  0.14898085594177246
# Warning: updateRobotNN took too long:  0.2096552848815918
# Warning: updateRobotNN took too long:  0.169677734375
# Warning: updateRobotNN took too long:  0.18428802490234375
# Warning: updateRobotNN took too long:  0.1770775318145752
# Warning: updateRobotNN took too long:  0.20853853225708008
# Warning: updateRobotNN took too long:  0.23937368392944336
# Warning: updateRobotNN took too long:  0.175584077835083
# Warning: updateRobotNN took too long:  0.21872973442077637
# Warning: updateRobotNN took too long:  0.18277359008789062
# Warning: updateRobotNN took too long:  0.15835213661193848
# Warning: updateRobotNN took too long:  0.16393113136291504
# Warning: updateRobotNN took too long:  0.2643766403198242
# Warning: updateRobotNN took too long:  0.18547725677490234
# Warning: updateRobotNN took too long:  0.19398093223571777
# Warning: updateRobotNN took too long:  0.1560051441192627
# Warning: updateRobotNN took too long:  0.15576601028442383
# Warning: updateRobotNN took too long:  0.24270200729370117
# Warning: updateRobotNN took too long:  0.16090798377990723
# Warning: updateRobotNN took too long:  0.16318011283874512
# Warning: updateRobotNN took too long:  0.19025540351867676
# Warning: updateRobotNN took too long:  0.1758284568786621
# Warning: updateRobotNN took too long:  0.1643979549407959
# Warning: updateRobotNN took too long:  0.11163854598999023
# Warning: updateRobotNN took too long:  0.27501797676086426
# Warning: updateRobotNN took too long:  0.24921751022338867
# Warning: updateRobotNN took too long:  0.24162793159484863
# Warning: updateRobotNN took too long:  0.21533846855163574
# Warning: updateRobotNN took too long:  0.2508835792541504
# Warning: updateRobotNN took too long:  0.24701166152954102
# Warning: updateRobotNN took too long:  0.27579736709594727
# Warning: updateRobotNN took too long:  0.30531883239746094
# Warning: updateRobotNN took too long:  0.2954573631286621
# Warning: updateRobotNN took too long:  0.2650601863861084
# Warning: updateRobotNN took too long:  0.24230623245239258
# Warning: updateRobotNN took too long:  0.3354780673980713
# Warning: updateRobotNN took too long:  0.33612823486328125
# Warning: updateRobotNN took too long:  0.3572695255279541
# Warning: updateRobotNN took too long:  0.4042994976043701
# Warning: updateRobotNN took too long:  0.36114501953125
# Warning: updateRobotNN took too long:  0.3048214912414551
# Warning: updateRobotNN took too long:  0.28293585777282715
# Warning: updateRobotNN took too long:  0.2996847629547119
# Warning: updateRobotNN took too long:  0.29990148544311523
# Warning: updateRobotNN took too long:  0.3484959602355957
# Warning: updateRobotNN took too long:  0.3627207279205322
# Warning: updateRobotNN took too long:  0.4106435775756836
# Warning: updateRobotNN took too long:  0.34683990478515625
# Warning: updateRobotNN took too long:  0.41633129119873047
# Warning: updateRobotNN took too long:  0.36956214904785156
# Warning: updateRobotNN took too long:  0.33745670318603516
# Warning: updateRobotNN took too long:  0.3136472702026367
# Warning: updateRobotNN took too long:  0.30569028854370117
# Warning: updateRobotNN took too long:  0.335925817489624
# Warning: updateRobotNN took too long:  0.2731156349182129
# Warning: updateRobotNN took too long:  0.2611548900604248
# Warning: updateRobotNN took too long:  0.3167588710784912
# Warning: updateRobotNN took too long:  0.3076138496398926
# Warning: updateRobotNN took too long:  0.28832554817199707
# Warning: updateRobotNN took too long:  0.22674870491027832
# Warning: updateRobotNN took too long:  0.2761361598968506
# Warning: updateRobotNN took too long:  0.2490074634552002
# Warning: updateRobotNN took too long:  0.1900463104248047
# Warning: updateRobotNN took too long:  0.24909639358520508
# Warning: updateRobotNN took too long:  0.2209484577178955
# Warning: updateRobotNN took too long:  0.24048733711242676
# Warning: updateRobotNN took too long:  0.31532907485961914
# Warning: updateRobotNN took too long:  0.24563288688659668
# Warning: updateRobotNN took too long:  0.23178982734680176
# Warning: updateRobotNN took too long:  0.23622584342956543
# Warning: updateRobotNN took too long:  0.2964766025543213
# Warning: updateRobotNN took too long:  0.24909400939941406
# Warning: updateRobotNN took too long:  0.23509001731872559
# Warning: updateRobotNN took too long:  0.26863861083984375
# Warning: updateRobotNN took too long:  0.24740386009216309
# Warning: updateRobotNN took too long:  0.25233912467956543
# Warning: updateRobotNN took too long:  0.23015618324279785
# Warning: updateRobotNN took too long:  0.23267769813537598
# Warning: updateRobotNN took too long:  0.37512850761413574
# Warning: updateRobotNN took too long:  0.29100823402404785
# Warning: updateRobotNN took too long:  0.25016283988952637
# Warning: updateRobotNN took too long:  0.27264904975891113
# Warning: updateRobotNN took too long:  0.2999117374420166
# Warning: updateRobotNN took too long:  0.2823817729949951
# Warning: updateRobotNN took too long:  0.284470796585083
# Warning: updateRobotNN took too long:  0.25882935523986816
# Warning: updateRobotNN took too long:  0.27614498138427734
# Warning: updateRobotNN took too long:  0.2590203285217285
# Warning: updateRobotNN took too long:  0.2579338550567627
# Warning: updateRobotNN took too long:  0.3048105239868164
# Warning: updateRobotNN took too long:  0.30631327629089355
# Warning: updateRobotNN took too long:  0.4251892566680908
# Warning: updateRobotNN took too long:  0.2891566753387451
# Warning: updateRobotNN took too long:  0.3210594654083252
# Warning: updateRobotNN took too long:  0.31121277809143066
# Warning: updateRobotNN took too long:  0.28089213371276855
# Warning: updateRobotNN took too long:  0.29920196533203125
# Warning: updateRobotNN took too long:  0.27311205863952637
# Warning: updateRobotNN took too long:  0.32820844650268555
# Warning: updateRobotNN took too long:  0.33881139755249023
# Warning: updateRobotNN took too long:  0.26590871810913086
# Warning: updateRobotNN took too long:  0.28331875801086426
# Warning: updateRobotNN took too long:  0.3325169086456299
# Warning: updateRobotNN took too long:  0.2993929386138916
# Warning: updateRobotNN took too long:  0.2946152687072754
# Warning: updateRobotNN took too long:  0.31893420219421387
# Warning: updateRobotNN took too long:  0.2945709228515625
# Warning: updateRobotNN took too long:  0.35538697242736816
# Warning: updateRobotNN took too long:  0.36011481285095215
# Warning: updateRobotNN took too long:  0.34571361541748047
# Warning: updateRobotNN took too long:  0.3377964496612549
# Warning: updateRobotNN took too long:  0.2821824550628662
# Warning: updateRobotNN took too long:  0.3479888439178467
# Warning: updateRobotNN took too long:  0.3227815628051758
# Warning: updateRobotNN took too long:  0.3148181438446045
# Warning: updateRobotNN took too long:  0.30554676055908203
# Warning: updateRobotNN took too long:  0.34071850776672363
# Warning: updateRobotNN took too long:  0.31166696548461914
# Warning: updateRobotNN took too long:  0.3890805244445801
# Warning: updateRobotNN took too long:  0.3950483798980713
# Warning: updateRobotNN took too long:  0.3310098648071289
# Warning: updateRobotNN took too long:  0.44742512702941895
# Warning: updateRobotNN took too long:  0.29863405227661133
# Warning: updateRobotNN took too long:  0.28151607513427734
# Warning: updateRobotNN took too long:  0.27924323081970215
# Warning: updateRobotNN took too long:  0.26265501976013184
# Warning: updateRobotNN took too long:  0.273345947265625
# Warning: updateRobotNN took too long:  0.34168291091918945
# Warning: updateRobotNN took too long:  0.27500009536743164
# Warning: updateRobotNN took too long:  0.23408842086791992
# Warning: updateRobotNN took too long:  0.36464524269104004
# Warning: updateRobotNN took too long:  0.30957746505737305
# Warning: updateRobotNN took too long:  0.2760014533996582
# Warning: updateRobotNN took too long:  0.2634246349334717
# Warning: updateRobotNN took too long:  0.3499135971069336
# Warning: updateRobotNN took too long:  0.38834333419799805
# Warning: updateRobotNN took too long:  0.251284122467041
# Warning: updateRobotNN took too long:  0.29779839515686035
# Warning: updateRobotNN took too long:  0.3238489627838135
# Warning: updateRobotNN took too long:  0.362231969833374
# Warning: updateRobotNN took too long:  0.3661811351776123
# Warning: updateRobotNN took too long:  0.32941293716430664
# Warning: updateRobotNN took too long:  0.32549238204956055
# Warning: updateRobotNN took too long:  0.3309454917907715
# Warning: updateRobotNN took too long:  0.2719693183898926
# Warning: updateRobotNN took too long:  0.27094364166259766
# Warning: updateRobotNN took too long:  0.309887170791626
# Warning: updateRobotNN took too long:  0.28898119926452637
# Warning: updateRobotNN took too long:  0.26725125312805176
# Warning: updateRobotNN took too long:  0.2576460838317871
# Warning: updateRobotNN took too long:  0.30728578567504883
# Warning: updateRobotNN took too long:  0.3209083080291748
# Warning: updateRobotNN took too long:  0.30905723571777344
# Warning: updateRobotNN took too long:  0.3167097568511963
# Warning: updateRobotNN took too long:  0.33343052864074707
# Warning: updateRobotNN took too long:  0.3441948890686035
# Warning: updateRobotNN took too long:  0.30793285369873047
# Warning: updateRobotNN took too long:  0.2933003902435303
# Warning: updateRobotNN took too long:  0.30757880210876465
# Warning: updateRobotNN took too long:  0.2601306438446045
# Warning: updateRobotNN took too long:  0.2378683090209961
# Warning: updateRobotNN took too long:  0.2580132484436035
# Warning: updateRobotNN took too long:  0.26849865913391113
# Warning: updateRobotNN took too long:  0.25151515007019043
# Warning: updateRobotNN took too long:  0.26462697982788086
# Warning: updateRobotNN took too long:  0.3907158374786377
# Warning: updateRobotNN took too long:  0.363628625869751
# Warning: updateRobotNN took too long:  0.43607234954833984
# Warning: updateRobotNN took too long:  0.40212035179138184
# Warning: updateRobotNN took too long:  0.3980252742767334
# Warning: updateRobotNN took too long:  0.4352748394012451
# Warning: updateRobotNN took too long:  0.3920774459838867
# Warning: updateRobotNN took too long:  0.407001256942749
# Warning: updateRobotNN took too long:  0.42206740379333496
# Warning: updateRobotNN took too long:  0.3947577476501465
# Warning: updateRobotNN took too long:  0.3669896125793457
# Warning: updateRobotNN took too long:  0.35378122329711914
# Warning: updateRobotNN took too long:  0.4073958396911621
# Warning: updateRobotNN took too long:  0.480701208114624
# Warning: updateRobotNN took too long:  0.4665806293487549
# Warning: updateRobotNN took too long:  0.44211769104003906
# Warning: updateRobotNN took too long:  0.43116164207458496
# Warning: updateRobotNN took too long:  0.45507025718688965
# Warning: updateRobotNN took too long:  0.4310920238494873
# Warning: updateRobotNN took too long:  0.36199116706848145
# Warning: updateRobotNN took too long:  0.38901281356811523
# Warning: updateRobotNN took too long:  0.4038257598876953
# Warning: updateRobotNN took too long:  0.3864259719848633
# Warning: updateRobotNN took too long:  0.3616206645965576
# Warning: updateRobotNN took too long:  0.34524989128112793
# Warning: updateRobotNN took too long:  0.33267903327941895
# Warning: updateRobotNN took too long:  0.35702991485595703
# Warning: updateRobotNN took too long:  0.3252420425415039
# Warning: updateRobotNN took too long:  0.3329746723175049
# Warning: updateRobotNN took too long:  0.3779029846191406
# Warning: updateRobotNN took too long:  0.36240077018737793
# Warning: updateRobotNN took too long:  0.36426472663879395
# Warning: updateRobotNN took too long:  0.4005873203277588
# Warning: updateRobotNN took too long:  0.3736531734466553
# Warning: updateRobotNN took too long:  0.37357115745544434
# Warning: updateRobotNN took too long:  0.3976762294769287
# Warning: updateRobotNN took too long:  0.3449740409851074
# Warning: updateRobotNN took too long:  0.3442554473876953
# Warning: updateRobotNN took too long:  0.3798708915710449
# Warning: updateRobotNN took too long:  0.340198278427124
# Warning: updateRobotNN took too long:  0.3579740524291992
# Warning: updateRobotNN took too long:  0.3880147933959961
# Warning: updateRobotNN took too long:  0.31688952445983887
# Warning: updateRobotNN took too long:  0.37239718437194824
# Warning: updateRobotNN took too long:  0.3523590564727783
# Warning: updateRobotNN took too long:  0.40526533126831055
# Warning: updateRobotNN took too long:  0.39612722396850586
# Warning: updateRobotNN took too long:  0.43462491035461426
# Warning: updateRobotNN took too long:  0.4199392795562744
# Warning: updateRobotNN took too long:  0.390289306640625
# Warning: updateRobotNN took too long:  0.4311182498931885
# Warning: updateRobotNN took too long:  0.3739793300628662
# Warning: updateRobotNN took too long:  0.4092681407928467
# Warning: updateRobotNN took too long:  0.3848567008972168
# Warning: updateRobotNN took too long:  0.37776923179626465
# Warning: updateRobotNN took too long:  0.38460254669189453
# Warning: updateRobotNN took too long:  0.38450169563293457
# Warning: updateRobotNN took too long:  0.3678433895111084
# Warning: updateRobotNN took too long:  0.419741153717041
# Warning: updateRobotNN took too long:  0.3603522777557373
# Warning: updateRobotNN took too long:  0.3717491626739502
# Warning: updateRobotNN took too long:  0.352557897567749
# Warning: updateRobotNN took too long:  0.3495323657989502
# Warning: updateRobotNN took too long:  0.3867170810699463
# Warning: updateRobotNN took too long:  0.3252685070037842
# Warning: updateRobotNN took too long:  0.3381180763244629
# Warning: updateRobotNN took too long:  0.390979528427124
# Warning: updateRobotNN took too long:  0.3489525318145752
# Warning: updateRobotNN took too long:  0.36989307403564453
# Warning: updateRobotNN took too long:  0.3890421390533447
# Warning: updateRobotNN took too long:  0.30727171897888184
# Warning: updateRobotNN took too long:  0.32853102684020996
# Warning: updateRobotNN took too long:  0.3847084045410156
# Warning: updateRobotNN took too long:  0.35956454277038574
# Warning: updateRobotNN took too long:  0.36165952682495117
# Warning: updateRobotNN took too long:  0.39103174209594727
# Warning: updateRobotNN took too long:  0.3590860366821289
# Warning: updateRobotNN took too long:  0.380800724029541
# Warning: updateRobotNN took too long:  0.3457200527191162
# Warning: updateRobotNN took too long:  0.3835563659667969
# Warning: updateRobotNN took too long:  0.4291801452636719
# Warning: updateRobotNN took too long:  0.3995544910430908
# Warning: updateRobotNN took too long:  0.41008543968200684
# Warning: updateRobotNN took too long:  0.3790469169616699
# Warning: updateRobotNN took too long:  0.3888401985168457
# Warning: updateRobotNN took too long:  0.38866567611694336
# Warning: updateRobotNN took too long:  0.3632361888885498
# Warning: updateRobotNN took too long:  0.3856382369995117
# Warning: updateRobotNN took too long:  0.3663330078125
# Warning: updateRobotNN took too long:  0.35777759552001953
# Warning: updateRobotNN took too long:  0.3902742862701416
# Warning: updateRobotNN took too long:  0.382523775100708
# Warning: updateRobotNN took too long:  0.33194422721862793
# Warning: updateRobotNN took too long:  0.35734081268310547
# Warning: updateRobotNN took too long:  0.3438100814819336
# Warning: updateRobotNN took too long:  0.35319089889526367
# Warning: updateRobotNN took too long:  0.3625187873840332
# Warning: updateRobotNN took too long:  0.38532018661499023
# Warning: updateRobotNN took too long:  0.3383777141571045
# Warning: updateRobotNN took too long:  0.42555975914001465
# Warning: updateRobotNN took too long:  0.37009596824645996
# Warning: updateRobotNN took too long:  0.3751239776611328
# Warning: updateRobotNN took too long:  0.34110093116760254
# Warning: updateRobotNN took too long:  0.3546566963195801
# Warning: updateRobotNN took too long:  0.37686896324157715
# Warning: updateRobotNN took too long:  0.3700904846191406
# Warning: updateRobotNN took too long:  0.369948148727417
# Warning: updateRobotNN took too long:  0.35379743576049805
# Warning: updateRobotNN took too long:  0.36949968338012695
# Warning: updateRobotNN took too long:  0.37361717224121094
# Warning: updateRobotNN took too long:  0.33406591415405273
# Warning: updateRobotNN took too long:  0.4646625518798828
# Warning: updateRobotNN took too long:  0.4565460681915283
# Warning: updateRobotNN took too long:  0.518038272857666
# Warning: updateRobotNN took too long:  0.45916318893432617
# Warning: updateRobotNN took too long:  0.499375581741333
# Warning: updateRobotNN took too long:  0.4866447448730469
# Warning: updateRobotNN took too long:  0.47649264335632324
# Warning: updateRobotNN took too long:  0.44234704971313477
# Warning: updateRobotNN took too long:  0.4279670715332031
# Warning: updateRobotNN took too long:  0.5175700187683105
# Warning: updateRobotNN took too long:  0.49604034423828125
# Warning: updateRobotNN took too long:  0.45612120628356934
# Warning: updateRobotNN took too long:  0.49676060676574707
# Warning: updateRobotNN took too long:  0.5077328681945801
# Warning: updateRobotNN took too long:  0.4853644371032715
# Warning: updateRobotNN took too long:  0.5010514259338379
# Warning: updateRobotNN took too long:  0.4947202205657959
# Warning: updateRobotNN took too long:  0.4893646240234375
# Warning: updateRobotNN took too long:  0.4890909194946289
# Warning: updateRobotNN took too long:  0.5288927555084229
# Warning: updateRobotNN took too long:  0.5010383129119873
# Warning: updateRobotNN took too long:  0.5851809978485107
# Warning: updateRobotNN took too long:  0.5159919261932373
# Warning: updateRobotNN took too long:  0.5078692436218262
# Warning: updateRobotNN took too long:  0.5522816181182861
# Warning: updateRobotNN took too long:  0.5047242641448975
# Warning: updateRobotNN took too long:  0.6406536102294922
# Warning: updateRobotNN took too long:  0.6145949363708496
# Warning: updateRobotNN took too long:  0.6308608055114746
# Warning: updateRobotNN took too long:  0.5358803272247314
# Warning: updateRobotNN took too long:  0.59116530418396
# Warning: updateRobotNN took too long:  0.4986848831176758
# Warning: updateRobotNN took too long:  0.5519206523895264
# Warning: updateRobotNN took too long:  0.5369868278503418
# Warning: updateRobotNN took too long:  0.5473742485046387
# Warning: updateRobotNN took too long:  0.4741220474243164
# Warning: updateRobotNN took too long:  0.5145680904388428
# Warning: updateRobotNN took too long:  0.5059113502502441
# Warning: updateRobotNN took too long:  0.4870893955230713
# Warning: updateRobotNN took too long:  0.4872434139251709
# Warning: updateRobotNN took too long:  0.49626922607421875
# Warning: updateRobotNN took too long:  0.49973511695861816
# Warning: updateRobotNN took too long:  0.4518880844116211
# Warning: updateRobotNN took too long:  0.472733736038208
# Warning: updateRobotNN took too long:  0.5541281700134277
# Warning: updateRobotNN took too long:  0.4244062900543213
# Warning: updateRobotNN took too long:  0.4647800922393799
# Warning: updateRobotNN took too long:  0.45016050338745117
# Warning: updateRobotNN took too long:  0.48297786712646484
# Warning: updateRobotNN took too long:  0.5715274810791016
# Warning: updateRobotNN took too long:  0.5283324718475342
# Warning: updateRobotNN took too long:  0.5029406547546387
# Warning: updateRobotNN took too long:  0.4779319763183594
# Warning: updateRobotNN took too long:  0.5509393215179443
# Warning: updateRobotNN took too long:  0.5052220821380615
# Warning: updateRobotNN took too long:  0.5606012344360352
# Warning: updateRobotNN took too long:  0.5583662986755371
# Warning: updateRobotNN took too long:  0.4824826717376709

# %%
modelControllingRobot = False
reset()
# Out:
# Warning: updateRobotNN took too long:  0.9233591556549072
# 4
